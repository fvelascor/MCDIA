# %% [markdown]
# <a href="https://colab.research.google.com/github/fvelascor/MCDIA/blob/master/Hands_On_Limpieza_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HANDS - ON: LIMPIEZA DE DATOS**

# %% [markdown]
# Una vez visto la presentación ***Limpieza de datos***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.
#
# Para este notebook, se hará uso del siguiente dataset: [enlace](https://drive.google.com/file/d/1X8v6zs9eDBVXPAQK9veDwINo4-H3mIPU/view?usp=drive_link)
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/1yQmEO8AuICLYlBsAEA6LURzY1v_zJ2TA?usp=sharing).

# %% [markdown]
# ## **RECOPILACIÓN DE DATOS**

# %% [markdown]
# La **recopilación de datos** es el **proceso de reunir y medir datos sobre un tema o fenómeno específico** que puedan ser analizados para responder preguntas de investigación, tomar decisiones informadas o comprender mejor un tema en particular. Esto implica:
#
# *   **Seleccionar un método de recolección adecuado** (como encuestas, entrevistas, observaciones, o el uso de datos existentes).
# *   **Aplicar dicho método de manera sistemática**.
# *   **Registrar los resultados obtenidos**.
#
# **Existen diversas fuentes confiables** donde puedes recopilar datos para análisis, dependiendo del tipo de información que necesites.
#
# Algunos sitios webs que ofrecen conjuntos de datos publicos y gratuitos son:
#
# *  [**Kaggle**](https://www.kaggle.com/datasets)
# *  [**Reddit**](https://www.reddit.com/r/datasets/)
# *  [**ONU**](https://data.un.org/)
# *  [**OMS**](https://www.who.int/data/collections)
# *  [**WB**](https://datos.bancomundial.org/)
# *  [**INEGI**](https://www.inegi.org.mx/datosabiertos/)
# *  [**Gobierno de México**](https://datos.gob.mx/busca/dataset)
# *  [**Sistema CDMX**](https://datos.cdmx.gob.mx/dataset/)

# %% [markdown]
# #### **IMPORTACIÓN DE DATOS**

# %% [markdown]
# Existen **diferentes formas de importar datos en Google Colab**, lo que lo convierte en una herramienta versátil para el análisis y la manipulación de datos.

# %%
# Importar librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### **ARCHIVO LOCAL**

# %% [markdown]
# Para **acceder a datos almacenados localmente** en tu ordenador, puedes utilizar las siguientes funciones de ***Pandas***, dependiendo del formato de archivo en el que se encuentren tus datos:
#
#
# *   **Sintaxis CSV:**
#
# ```
# pd.read_csv('ruta/archivo.csv')
# ```
#
# *   **Sintaxis Excel:**
#
# ```
# pd.read_excel('ruta/al/archivo.xlsx')
# ```
#
# *   **Sintaxis JSON:**
#
# ```
# pd.read_json('ruta/archivo.json')
# ```
#
# Para conocer los formatos de archivos restantes a las que se pueden acceder, será necesario consultar la [documentación](https://pandas.pydata.org/docs/reference/io.html).

# %% [markdown]
# ***Google Colaboratory*** opera en un **entorno virtualizado**, lo que implica que no tiene acceso directo al sistema de archivos de tu máquina local. Por lo tanto, para trabajar con archivos almacenados en tu ordenador, es necesario acudir a otras alternativass.
#
# *   Importar datos directamente desde **Google Colaboratory**, aunque esta opcióN solo es temporal.
#
# *   Utilizar otros **entornos de almacenamiento** para cargarlos al entorno de ***Colab***.

# %%
# Importar datos desde Google Colab
url = 'https://drive.google.com/uc?id=1X8v6zs9eDBVXPAQK9veDwINo4-H3mIPU'

df = pd.read_csv(url)

df.head()
# Out:
#    video_id         título     categoría     views    likes  dislikes  \
# 0         1   Título 1###       musica         NaN      NaN        21
# 1         2   Título 2@@@    películas    247904.0  15579.0       211
# 2         3            NaN   comedia!!!     3073.0  14780.0      1095
# 3         4     Título 4        gaming    268858.0   2691.0      4420
# 4         5     Título 5      Gaming!!!   162893.0  16521.0      2294
#
#    comentarios  duración_min fecha_publicación
# 0         8790           127        2024/07/02
# 1         4775            63         2.13.2022
# 2         9847            55        07-06-2016
# 3         7614            78         12.3.2017
# 4         6508           143        2023-11-24

# %% [markdown]
# ##### **GITHUB**

# %% [markdown]
# Si los datos están almacenados en ***GitHub***, basta con tener la liga que proporciona la opción **raw** dentro del repositorio para acceder a ellos.

# %%
# Importar datos desde GitHub

# %% [markdown]
# ##### **GOOGLE DRIVE**

# %% [markdown]
# Si los datos están almacenados en ***Google Drive***, se puede montar en ***Colab*** y acceder a ellos. Para ello se puede seguir la siguiente sintaxis:
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```
#
# De manera posterior, el procedimeinto para **acceder a los datos es igual a la formas anteriores**.

# %%
# Montar Google Drive
from google.colab import drive

# Montar Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar datos desde Google Drive
import pandas as pd

# Enlace directo de descarga
url = 'https://drive.google.com/uc?id=1X8v6zs9eDBVXPAQK9veDwINo4-H3mIPU'

# Leer CSV
df = pd.read_csv(url)

# Mostrar primeras filas
df.head()
# Out:
#    video_id         título     categoría     views    likes  dislikes  \
# 0         1   Título 1###       musica         NaN      NaN        21
# 1         2   Título 2@@@    películas    247904.0  15579.0       211
# 2         3            NaN   comedia!!!     3073.0  14780.0      1095
# 3         4     Título 4        gaming    268858.0   2691.0      4420
# 4         5     Título 5      Gaming!!!   162893.0  16521.0      2294
#
#    comentarios  duración_min fecha_publicación
# 0         8790           127        2024/07/02
# 1         4775            63         2.13.2022
# 2         9847            55        07-06-2016
# 3         7614            78         12.3.2017
# 4         6508           143        2023-11-24

# %% [markdown]
# Cuando la forma anterior no funcione debido a que **Google Drive cambie el tipo de dato** del archivo, existen otras alternativas de acceder a los datos.

# %% [markdown]
# ## **SANEAMIENTO DE DATOS**

# %% [markdown]
# **El saneamiento es la etapa donde se busca asegurar la integridad el conjunto de datos.** Un dataset crudo suele contener inconsistencias que pueden sesgar nuestros análisis.
#
# Cuando se comienza el saneamiento de datos, **se busca limpiar del dataset en la corrección de valores nulos (vacíos)**.

# %%
# Ver tipos de datos
# Mostrar tipos de datos de cada columna
df.dtypes
# Out:
# video_id               int64
# título                object
# categoría             object
# views                float64
# likes                float64
# dislikes               int64
# comentarios            int64
# duración_min           int64
# fecha_publicación     object
# dtype: object

# %%
# Verificar valores nulos por columna
df.isnull().sum()
# Out:
# video_id              0
# título               26
# categoría            25
# views                24
# likes                24
# dislikes              0
# comentarios           0
# duración_min          0
# fecha_publicación     0
# dtype: int64

# %%
# Observar los primeros 10 registros
df.head(10)
# Out:
#    video_id          título     categoría     views    likes  dislikes  \
# 0         1    Título 1###       musica         NaN      NaN        21
# 1         2    Título 2@@@    películas    247904.0  15579.0       211
# 2         3             NaN   comedia!!!     3073.0  14780.0      1095
# 3         4      Título 4        gaming    268858.0   2691.0      4420
# 4         5      Título 5      Gaming!!!   162893.0  16521.0      2294
# 5         6    Título 6@@@    películas     42160.0  10721.0      3547
# 6         7       Título 7        música    90723.0   6461.0      2057
# 7         8    Título 8!!!    Comedia!!!   166255.0  10284.0    300408
# 8         9    Título 9!!!            NaN   94776.0  19339.0      1855
# 9        10   Título 10???     Musica???       -1.0  17151.0       458
#
#    comentarios  duración_min fecha_publicación
# 0         8790           127        2024/07/02
# 1         4775            63         2.13.2022
# 2         9847            55        07-06-2016
# 3         7614            78         12.3.2017
# 4         6508           143        2023-11-24
# 5         9033            58         8.27.2025
# 6         5150           219        2021-05-04
# 7         7206           115        2019/10/15
# 8         2847           207         7.18.2017
# 9         9632           164        2023/08/26

# %% [markdown]
# ### **VARIABLES DE TEXTO**

# %% [markdown]
# La **limpieza de datos para columnas de texto** se separa porque este tipo de datos presenta desafíos y requerimientos de preprocesamiento únicos. A diferencia de los datos numéricos, las columnas de texto pueden contener:
#
#
# *   **Valores faltantes :** Se deben imputar o eliminar.
#
# *   **Errores tipográficos y variaciones:** Palabras mal escritas, uso inconsistente de mayúsculas/minúsculas, abreviaturas, etc.
#
# *   **Caracteres especiales y símbolos:** Signos de puntuación, emojis, caracteres no alfanuméricos que no aportan valor al análisis.
#
# *   **Espacios extra o formatos inconsistentes:** Espacios al inicio/final, múltiples espacios entre palabras.
#
# *   **Valores semánticamente similares:** Palabras que significan lo mismo pero están escritas de forma diferente.

# %% [markdown]
# #### **IMPUTACIÓN**

# %% [markdown]
# La **imputación de datos** es el proceso de reemplazar los valores faltantes o nulos en un conjunto de datos con valores sustitutos.
#
# El objetivo principal de la imputación es **mantener la integridad del conjunto de datos y evitar la pérdida de información** que ocurriría si simplemente se eliminaran las filas o columnas con valores faltantes.

# %%
# Verificar valores nulos por columna de texto
df.select_dtypes(include='object').isnull().sum()
# Out:
# título               26
# categoría            25
# fecha_publicación     0
# dtype: int64

# %%
# Visualizar los primeros 10 registros nulos
df[df.isnull().any(axis=1)].head(10)
# Out:
#     video_id          título        categoría     views    likes  dislikes  \
# 0          1    Título 1###          musica         NaN      NaN        21
# 2          3             NaN      comedia!!!     3073.0  14780.0      1095
# 8          9    Título 9!!!               NaN   94776.0  19339.0      1855
# 10        11      Título 11    Tecnología???        NaN  16673.0      3851
# 12        13             NaN              NaN   35750.0  15682.0      1881
# 15        16             NaN    Peliculas???   197860.0  12791.0      2292
# 21        22   Título 22###      noticias!!!        NaN   9557.0      2862
# 22        23     Título 23                NaN  184431.0   3302.0      2232
# 25        26             NaN      Comedia???    69141.0   4651.0      4730
# 29        30   Título 30###               NaN  166500.0   7327.0      2890
#
#     comentarios  duración_min fecha_publicación
# 0          8790           127        2024/07/02
# 2          9847            55        07-06-2016
# 8          2847           207         7.18.2017
# 10         6233            80        2025/05/04
# 12         4607           178        2017/11/02
# 15         1141           800        13-06-2020
# 21         5531           171        2020-05-06
# 22         9615            46        2020/12/06
# 25         9698            12        25-11-2025
# 29         2882           220        06-01-2022

# %%
  # Imputación de datos por nueva categoría
df.columns
df["categoría"] = df["categoría"].fillna("Desconocido")

# %% [markdown]
# #### **NORMALIZACIÓN**

# %% [markdown]
# En ocasiones, ciertos registros de texto suelen tener **símbolos especiales** como `!!!`, `@@@`, espacios extra, etc. Con el uso de **Expresiones Regulares (REGEX) se limpia el texto de los símbolos expeciales.**

#  ' Tecnologia??? ' ' Deportes@@@ ' ' películas??? ' ' gaming@@@ '
#  ' Tecnología!!! ' ' noticias!!! ' ' educacion  ' ' Películas  '
#  ' Gaming??? ' ' tecnología  ' ' deportes  ' ' tecnología@@@ '
#  ' Peliculas### ' ' Películas@@@ ' ' Noticias@@@ ' ' comedia '
#  ' peliculas ' ' comedia  ' ' noticias### ' ' educación ' ' Comedia### '
#  ' Peliculas ' ' peliculas  ' ' deportes ' ' Noticias ' ' música??? '
#  ' tecnologia ' ' Deportes ' ' comedia### ' ' Educación??? '
#  ' Noticias??? ' ' educacion!!! ' ' educacion ' ' noticias ' ' Musica@@@ '
#  ' Deportes??? ' ' Gaming### ' ' deportes### ' ' gaming??? '
#  ' tecnología!!! ' ' educacion### ' ' Deportes### ' ' noticias  '
#  ' Películas### ' ' peliculas??? ' ' Peliculas!!! ' ' Gaming  '
#  ' Noticias!!! ' ' deportes@@@ ' ' musica??? ' ' peliculas!!! '
#  ' Noticias  ' ' Películas ' ' tecnología??? ' ' Gaming ' ' música@@@ '
#  ' Música ' ' Gaming@@@ ' ' Comedia  ' ' gaming!!! ' ' peliculas@@@ '
#  ' tecnologia!!! ' ' Tecnologia@@@ ' ' Comedia@@@ ' ' tecnologia@@@ '
#  ' Tecnología  ' ' Música!!! ' ' Noticias### ' ' educación  '
#  ' educación### ' ' música### ' ' Deportes!!! ' ' Películas!!! '
#  ' noticias??? ' ' Educacion!!! ' ' tecnologia### ' ' Educacion### '
#  ' musica!!! ' ' musica### ' ' musica ' ' películas!!! ' ' Educacion  '
#  ' comedia@@@ ' ' Educacion??? ' ' Música  ' ' noticias@@@ '
#  ' películas### ' ' Musica ' ' Musica  ' ' Educación ' ' Comedia '
#  ' gaming### ' ' películas@@@ ' ' gaming ' ' Música??? ' ' deportes??? '
#  ' Tecnologia!!! ' ' peliculas### ' ' educacion@@@ ' ' música  '
#  ' música!!! ' ' Musica!!! ' ' Tecnología@@@ ' ' Deportes  ']
#
# Columna: fecha_publicación
# ['2024/07/02' '2.13.2022' '07-06-2016' '12.3.2017' '2023-11-24'
#  '8.27.2025' '2021-05-04' '2019/10/15' '7.18.2017' '2023/08/26'
#  '2025/05/04' '2.25.2016' '2017/11/02' '4.21.2022' '27-01-2015'
#  '13-06-2020' '18-02-2021' '23-05-2016' '2016/01/17' '2025-07-27'
#  '2019-02-17' '2020-05-06' '2020/12/06' '10.12.2017' '17-01-2017'
#  '25-11-2025' '2018/06/04' '06-01-2019' '12.14.2019' '06-01-2022'
#  '4.15.2020' '1.9.2019' '2023-11-26' '1.1.2018' '21-02-2025' '25-11-2015'
#  '2022/05/23' '1.5.2025' '2018-04-23' '4.6.2020' '2.19.2017' '9.16.2016'
#  '12.18.2016' '2018-12-18' '09-10-2025' '7.28.2019' '13-12-2017'
#  '2023/06/13' '2024/05/08' '2017-05-04' '1.16.2022' '6.6.2022'
#  '2024-08-03' '2018-02-25' '2018-12-23' '7.19.2019' '2024-12-02'
#  '2021-01-10' '2025-01-05' '7.11.2016' '19-07-2017' '3.15.2023'
#  '8.19.2024' '2021/12/04' '2016-02-14' '6.18.2019' '5.10.2024'
#  '2016-02-17' '6.11.2022' '2020-09-20' '2017-07-28' '2016-12-28'
#  '2019/08/06' '2019/08/09' '2018-10-05' '27-11-2017' '10.14.2016'
#  '2022/04/10' '18-04-2022' '12.1.2023' '10-07-2016' '11.12.2022'
#  '11-03-2018' '2022/10/07' '6.7.2025' '12.26.2019' '2021/10/27'
#  '18-04-2015' '05-07-2015' '2021/08/12' '2022/09/23' '2019-04-15'
#  '3.15.2019' '2025-06-02' '28-10-2016' '2016/01/28' '08-03-2016'
#  '2024-04-20' '26-01-2015' '1.1.2023' '15-02-2016' '2017/06/19'
#  '1.13.2019' '2021-11-04' '3.17.2021' '2018-07-20' '23-03-2024'
#  '06-09-2016' '2025/12/25' '2021/04/26' '2023-05-21' '2023/01/03']

# %%
# Definir función de eliminar caracteres especiales y espacios extras
import re

def limpiar_texto(texto):

    # Convertir a string
    texto = str(texto)

    # Convertir a minúsculas
    texto = texto.lower()

    # Eliminar caracteres especiales
    texto = re.sub(r'[^a-zA-Z0-9\s]', '', texto)

    # Eliminar espacios extras
    texto = re.sub(r'\s+', ' ', texto).strip()

    return texto

# %%
# Aplicar limpieza a columnas con texto
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].apply(limpiar_texto)

# %%
# Observar cambios en los valores únicos
for col in df.select_dtypes(include='object').columns:
    print(f"\nColumna: {col}")
    print(df[col].unique())
# Out:
# Columna: título
# ['ttulo 1' 'ttulo 2' 'nan' 'ttulo 4' 'ttulo 5' 'ttulo 6' 'ttulo 7'
#  'ttulo 8' 'ttulo 9' 'ttulo 10' 'ttulo 11' 'ttulo 12' 'ttulo 14'
#  'ttulo 15' 'ttulo 17' 'ttulo 18' 'ttulo 19' 'ttulo 20' 'ttulo 21'
#  'ttulo 22' 'ttulo 23' 'ttulo 24' 'ttulo 25' 'ttulo 27' 'ttulo 28'
#  'ttulo 29' 'ttulo 30' 'ttulo 31' 'ttulo 32' 'ttulo 34' 'ttulo 35'
#  'ttulo 37' 'ttulo 38' 'ttulo 39' 'ttulo 41' 'ttulo 42' 'ttulo 43'
#  'ttulo 44' 'ttulo 45' 'ttulo 46' 'ttulo 47' 'ttulo 48' 'ttulo 49'
#  'ttulo 50' 'ttulo 51' 'ttulo 52' 'ttulo 53' 'ttulo 54' 'ttulo 55'
#  'ttulo 56' 'ttulo 57' 'ttulo 58' 'ttulo 59' 'ttulo 60' 'ttulo 61'
#  'ttulo 62' 'ttulo 63' 'ttulo 64' 'ttulo 65' 'ttulo 66' 'ttulo 67'
#  'ttulo 68' 'ttulo 71' 'ttulo 72' 'ttulo 75' 'ttulo 76' 'ttulo 77'
#  'ttulo 78' 'ttulo 79' 'ttulo 80' 'ttulo 81' 'ttulo 82' 'ttulo 83'
#  'ttulo 84' 'ttulo 85' 'ttulo 86' 'ttulo 88' 'ttulo 89' 'ttulo 91'
#  'ttulo 92' 'ttulo 94' 'ttulo 95' 'ttulo 96' 'ttulo 97' 'ttulo 98'
#  'ttulo 99' 'ttulo 100' 'ttulo 101' 'ttulo 102' 'ttulo 103' 'ttulo 104'
#  'ttulo 105' 'ttulo 106' 'ttulo 107' 'ttulo 108' 'ttulo 109' 'ttulo 110'
#  '6112022' '20200920' '20170728' '20161228' '20190806' '20190809'
#  '20181005' '27112017' '10142016' '20220410' '18042022' '1212023'
#  '10072016' '11122022' '11032018' '20221007' '672025' '12262019'
#  '20211027' '18042015' '05072015' '20210812' '20220923' '20190415'
#  '3152019' '20250602' '28102016' '20160128' '08032016' '20240420'
#  '26012015' '112023' '15022016' '20170619' '1132019' '20211104' '3172021'
#  '20180720' '23032024' '06092016' '20251225' '20210426' '20230521'
#  '20230103']

# %%
df.columns
# Out:
# Index(['video_id', 'título', 'categoría', 'views', 'likes', 'dislikes',
#        'comentarios', 'duración_min', 'fecha_publicación'],
#       dtype='object')

# %%
# Corregir detalles de texto adicionales
df["categoría"] = df["categoría"].replace({
    "music ": "music",
    "gaming ": "gaming",
    "education ": "education"
})

df["título"] = df["título"].str.strip()

# %%
# Cambio de tipo de dato
df["fecha_publicación"] = pd.to_datetime(
    df["fecha_publicación"],
    format="mixed",
    errors="coerce"
)

# %%
#revisa cuáles registros fallaron:
df[df["fecha_publicación"].isnull()]
# Out:
#      video_id     título    categoría     views    likes  dislikes  \
# 2           3        nan      comedia    3073.0  14780.0    1095.0
# 3           4    ttulo 4       gaming  268858.0   2691.0    4420.0
# 5           6    ttulo 6     pelculas   42160.0  10721.0    3547.0
# 8           9    ttulo 9  desconocido   94776.0  19339.0    1855.0
# 13         14   ttulo 14    peliculas   84442.0   7701.0    4900.0
# ..        ...        ...          ...       ...      ...       ...
# 294       295  ttulo 295    tecnologa   96276.0  14988.0    2629.0
# 295       296  ttulo 296   tecnologia  240627.0  12230.0    3168.0
# 303       106  ttulo 106    peliculas  150272.0  11299.0    4605.0
# 305         6    ttulo 6     pelculas   42160.0  10721.0    3547.0
# 307       210  ttulo 210    peliculas   71075.0  19940.0     223.0
#
#      comentarios  duración_min fecha_publicación
# 2         9847.0          55.0               NaT
# 3         7614.0          78.0               NaT
# 5         9033.0          58.0               NaT
# 8         2847.0         207.0               NaT
# 13        8668.0          80.0               NaT
# ..           ...           ...               ...
# 294       4101.0         115.0               NaT
# 295       4313.0          49.0               NaT
# 303       6716.0         213.0               NaT
# 305       9033.0          58.0               NaT
# 307       2832.0          51.0               NaT
#
# [155 rows x 9 columns]

# %%
# Verificar cambio de típos de dato
df.dtypes
# Out:
# video_id                      int64
# título                       object
# categoría                    object
# views                       float64
# likes                       float64
# dislikes                    float64
# comentarios                 float64
# duración_min                float64
# fecha_publicación    datetime64[ns]
# dtype: object

# %% [markdown]
# #### **TRANSFORMACIÓN DE FECHAS**

# %% [markdown]
# Las fechas suelen ser uno de los tipos de datos más problemáticos debido a la multitud de formatos en los que pueden presentarse. La **transformación y estandarización de fechas** es crucial.

# %%
# Ver los primeros 10 registros
df.head(10)
# Out:
#    video_id    título    categoría     views    likes  dislikes  comentarios  \
# 0         1   ttulo 1       musica       NaN      NaN      21.0       8790.0
# 1         2   ttulo 2     pelculas  247904.0  15579.0     211.0       4775.0
# 2         3       nan      comedia    3073.0  14780.0    1095.0       9847.0
# 3         4   ttulo 4       gaming  268858.0   2691.0    4420.0       7614.0
# 4         5   ttulo 5       gaming  162893.0  16521.0    2294.0       6508.0
# 5         6   ttulo 6     pelculas   42160.0  10721.0    3547.0       9033.0
# 6         7   ttulo 7        msica   90723.0   6461.0    2057.0       5150.0
# 7         8   ttulo 8      comedia  166255.0  10284.0  300408.0       7206.0
# 8         9   ttulo 9  desconocido   94776.0  19339.0    1855.0       2847.0
# 9        10  ttulo 10       musica      -1.0  17151.0     458.0       9632.0
#
#    duración_min fecha_publicación
# 0         127.0        2024-07-02
# 1          63.0        2132-02-02
# 2          55.0               NaT
# 3          78.0               NaT
# 4         143.0        2023-11-24
# 5          58.0               NaT
# 6         219.0        2021-05-04
# 7         115.0        2019-10-15
# 8         207.0               NaT
# 9         164.0        2023-08-26

# %%
# Cambio de tipo de dato y normalización de formato

df["views"] = pd.to_numeric(df["views"], errors="coerce")
df["likes"] = pd.to_numeric(df["likes"], errors="coerce")
df["dislikes"] = pd.to_numeric(df["dislikes"], errors="coerce")
df["comentarios"] = pd.to_numeric(df["comentarios"], errors="coerce")
df["duración_min"] = pd.to_numeric(df["duración_min"], errors="coerce")

# Conversión y normalización de fechas
df["fecha_publicación"] = pd.to_datetime(
    df["fecha_publicación"],
    format="mixed",
    errors="coerce"
)

# Normalización de texto
for col in ["título", "categoría"]:
    df[col] = df[col].str.lower().str.strip()

# %%
# Verificar cambio de típo de dato
df.dtypes
# Out:
# video_id                      int64
# título                       object
# categoría                    object
# views                       float64
# likes                       float64
# dislikes                    float64
# comentarios                 float64
# duración_min                float64
# fecha_publicación    datetime64[ns]
# dtype: object

# %% [markdown]
# ### **VARIABLES NUMÉRICAS**

# %% [markdown]
# La **limpieza de datos para columnas numéricas** también se maneja por separado debido a la naturaleza distintiva de los problemas que pueden surgir con este tipo de datos y las metodologías específicas para abordarlos. Las columnas numéricas suelen presentar:
#
# *   **Valores faltantes :** Se deben imputar o eliminar.
#
# *   **Valores atípicos:** Datos que se desvían significativamente del patrón general, los cuales pueden ser errores o representaciones de fenómenos raros.
#
# *   **Inconsistencias de escala:** Rangos de valores muy diferentes entre columnas. Esto se aborda con normalización o estandarización.
#
# *   **Errores de entrada o lógica:** Valores negativos donde solo positivos son posibles, valores extremadamente grandes o pequeños que indican fallas en la recolección.

# %%
# Importar librerías de visualización
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ver tipos de datos
df.dtypes
# Out:
# video_id                      int64
# título                       object
# categoría                    object
# views                       float64
# likes                       float64
# dislikes                    float64
# comentarios                 float64
# duración_min                float64
# fecha_publicación    datetime64[ns]
# dtype: object

# %%
# Verificar valores nulos por columna numérica
df.select_dtypes(include=['int64', 'float64']).isnull().sum()
# Out:
# video_id         0
# views           24
# likes           24
# dislikes         0
# comentarios      0
# duración_min     0
# dtype: int64

# %% [markdown]
# #### **IMPUTACIÓN Y NORMALIZACIÓN**

# %% [markdown]
# En la fase de **imputación y normalización para variables numéricas**, el objetivo es asegurar que estos datos sean consistentes, completos y adecuados para el análisis.
#
# Estas acciones son cruciales para mantener la integridad del dataset y garantizar que los análisis posteriores no se vean afectados por datos faltantes o erróneos.

# %%
# Ver resumen estadístico de las columnas con nulos
df.select_dtypes(include=['int64', 'float64']).describe()
# Out:
#          video_id          views         likes       dislikes  comentarios  \
# count  308.000000     284.000000  2.840000e+02     308.000000   308.000000
# mean   149.996753  137926.799296  6.785967e+05   12193.288961  5058.188312
# std     86.209747   96538.282338  2.500358e+06   52900.153300  2940.396104
# min      1.000000      -1.000000  9.700000e+01      21.000000    12.000000
# 25%     76.750000   48809.250000  5.389750e+03    1523.750000  2667.500000
# 50%    149.500000  129257.000000  1.129900e+04    2590.000000  4931.500000
# 75%    223.250000  229829.500000  1.602150e+04    3777.500000  7740.750000
# max    300.000000  299408.000000  9.999999e+06  300408.000000  9987.000000
#
#        duración_min
# count    308.000000
# mean     139.853896
# std      139.066834
# min        1.000000
# 25%       58.000000
# 50%      123.500000
# 75%      181.500000
# max      800.000000

# %%
# Observar distribución de las columnas con nulos
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Graficar distribución de cada columna numérica
for col in num_cols:

    plt.figure(figsize=(8,5))

    sns.histplot(
        df[col],
        kde=True
    )

    plt.title(f"Distribución de {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")

    plt.show()

# %%
# Calcular media y desviación estándar de las columnas con nulos
for col in df.select_dtypes(include=['int64', 'float64']).columns:

    print(f"\nColumna: {col}")
    print(f"Media: {df[col].mean()}")
    print(f"Desviación estándar: {df[col].std()}")
# Out:
# Columna: video_id
# Media: 149.99675324675326
# Desviación estándar: 86.20974719019243
#
# Columna: views
# Media: 137926.79929577466
# Desviación estándar: 96538.28233835234
#
# Columna: likes
# Media: 678596.7394366197
# Desviación estándar: 2500357.927418338
#
# Columna: dislikes
# Media: 12193.288961038961
# Desviación estándar: 52900.15329951008
#
# Columna: comentarios
# Media: 5058.188311688312
# Desviación estándar: 2940.3961038966872
#
# Columna: duración_min
# Media: 139.8538961038961
# Desviación estándar: 139.06683446210906

# %%
# Observar distribución de las columnas con nulos
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:

    plt.figure(figsize=(8,5))

    sns.histplot(
        data=df,
        x=col,
        kde=True,
        bins=30
    )

    plt.title(f"Distribución de {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")
    plt.grid(True)

    plt.show()

# %%
# Imputación de datos
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    df[col] = df[col].fillna(df[col].mean())

# %%
# Cambio de tipo de dato
df["views"] = df["views"].astype(float)
df["likes"] = df["likes"].astype(float)
df["dislikes"] = df["dislikes"].astype(float)
df["comentarios"] = df["comentarios"].astype(float)
df["duración_min"] = df["duración_min"].astype(float)

# Conversión de fecha
df["fecha_publicación"] = pd.to_datetime(
    df["fecha_publicación"],
    format="mixed",
    errors="coerce"
)

# %%
# Ver tipos de datos
df.dtypes
# Out:
# video_id                      int64
# título                       object
# categoría                    object
# views                       float64
# likes                       float64
# dislikes                    float64
# comentarios                 float64
# duración_min                float64
# fecha_publicación    datetime64[ns]
# dtype: object

# %%
# Crear dataset final
df_final = df.copy()

# Visualizar primeras filas
df_final.head()
# Out:
#    video_id   título categoría          views          likes  dislikes  \
# 0         1  ttulo 1    musica  137926.799296  678596.739437      21.0
# 1         2  ttulo 2  pelculas  247904.000000   15579.000000     211.0
# 2         3      nan   comedia    3073.000000   14780.000000    1095.0
# 3         4  ttulo 4    gaming  268858.000000    2691.000000    4420.0
# 4         5  ttulo 5    gaming  162893.000000   16521.000000    2294.0
#
#    comentarios  duración_min fecha_publicación
# 0       8790.0         127.0        2024-07-02
# 1       4775.0          63.0        2132-02-02
# 2       9847.0          55.0               NaT
# 3       7614.0          78.0               NaT
# 4       6508.0         143.0        2023-11-24

# %% [markdown]
# ## **CHALLENGE: ALOJAMIENTO AIRBNB CDMX**

# %% [markdown]
# Una vez visto el ***Hands - On: Limpieza de datos***, se presentan las siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.
#
# Para este notebook, se hará uso del siguiente dataset: [enlace](https://drive.google.com/file/d/1F3WOQnwg5jFZD7rnW3IiTh0ObKCnSODd/view?usp=drive_link)

# %% [markdown]
# Dentro de la siguiente dinámica, **se realizará un proceso completo de limpieza y preparación de datos** sobre el catálogo de alojamientos de Airbnb en la Ciudad de México, con la finalidad de garantizar la calidad e integridad de la información antes de cualquier análisis posterior. Se hará uso de **herramientas de manipulación de datos, técnicas de imputación y análisis exploratorio** a través del dataset **"airbnb_cdmx"**.
#
# Donde los procesos a realizar son:
#
# * **Identificación y tratamiento de valores nulos por tipo de dato**.
# * **Estandarización de columnas categóricas y conversión de tipos de datos**.
# * **Imputación basada en distribución y resumen estadístico**.

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Importaciones y visualización de estructura:**
#
# * Carga las bibliotecas de Pandas, Seaborn y Matplotlib.pyplot.
# * Carga el archivo *airbnb_cdmx.csv*.
# * Visualiza los tipos de datos de las columnas.

# %%
# Importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importar dataset
import pandas as pd

# Enlace directo de descarga
url = "https://drive.google.com/uc?id=1F3WOQnwg5jFZD7rnW3IiTh0ObKCnSODd"

# Cargar dataset
df = pd.read_csv(url)

# Visualizar primeras filas
df.head()
# Out:
#       id                                              name  host_id host_name  \
# 0  35797                                       Villa Dante   153786      Dici
# 1  44616                                      Condesa Haus   196253  Fernando
# 2  56074              Great space in historical San Rafael   265650     Maris
# 3  67703                 2 bedroom apt. deco bldg, Condesa   334451  Nicholas
# 4  70644  Beautiful light Studio Coyoacan- full equipped !   212109    Trisha
#
#            neighbourhood  latitude  longitude        room_type    price  \
# 0  Cuajimalpa de Morelos  19.38283  -99.27178  Entire home/apt   3673.0
# 1             Cuauhtémoc  19.41162  -99.17794  Entire home/apt  18000.0
# 2             Cuauhtémoc  19.43977  -99.15605  Entire home/apt    591.0
# 3             Cuauhtémoc  19.41152  -99.16857  Entire home/apt      NaN
# 4               Coyoacán  19.35448  -99.16217  Entire home/apt      NaN
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               1                  0         NaN                NaN
# 1               1                 65  2025-01-01               0.38
# 2              15                 84  2025-02-27               0.48
# 3               2                 50  2024-10-30               0.30
# 4               3                134  2025-08-18               0.81
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                               1               363                      0
# 1                               9               360                      1
# 2                               1               333                      1
# 3                               2               252                      1
# 4                               3               234                      8

# %%
# Ver info de dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27051 entries, 0 to 27050
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              27051 non-null  int64
#  1   name                            27051 non-null  object
#  2   host_id                         27051 non-null  int64
#  3   host_name                       27045 non-null  object
#  4   neighbourhood                   27051 non-null  object
#  5   latitude                        27051 non-null  float64
#  6   longitude                       27051 non-null  float64
#  7   room_type                       27051 non-null  object
#  8   price                           23567 non-null  float64
#  9   minimum_nights                  27051 non-null  int64
#  10  number_of_reviews               27051 non-null  int64
#  11  last_review                     23650 non-null  object
#  12  reviews_per_month               23650 non-null  float64
#  13  calculated_host_listings_count  27051 non-null  int64
#  14  availability_365                27051 non-null  int64
#  15  number_of_reviews_ltm           27051 non-null  int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 3.3+ MB

# %%
# Ver tipos de datos
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# dtype: object

# %% [markdown]
# **2. Visualización de duplicados y valores nulos en columnas de texto:**
#
# * Verifica valores nulos y la existencia de registros duplicados.
# * Cuantifica los valores faltantes para las columnas de tipo texto.
# * Visualiza los primeros 10 registros nulos de cada columna.

# %%
# Detección de duplicados y valores nulos por columna
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Verificar valores nulos por columnas de texto
df.select_dtypes(include='object').isnull().sum()
# Out:
# name                0
# host_name           6
# neighbourhood       0
# room_type           0
# last_review      3401
# dtype: int64

# %%
# Visualizar los primeros 10 registros nulos
df[df.isnull().any(axis=1)].head(10)
# Out:
#         id                                              name  host_id  \
# 0    35797                                       Villa Dante   153786
# 3    67703                 2 bedroom apt. deco bldg, Condesa   334451
# 4    70644  Beautiful light Studio Coyoacan- full equipped !   212109
# 5   131610                                    MARIA DEL ALMA   647454
# 9   187030     Spacious apt with the best rooftop in Condesa   899360
# 10  187745          Extraordinarily Spacious Apt. in Condesa   899360
# 11  194937   Sunny & Fresh Apt. with best rooftop in Condesa   899360
# 18  276504                  High End Condo with golf package  1444589
# 19  281134                COOL PENT HOUSE APARTMENT @CONDESA   196253
# 21  291804                   A nice room with great location  1511568
#
#        host_name          neighbourhood  latitude  longitude        room_type  \
# 0           Dici  Cuajimalpa de Morelos  19.38283  -99.27178  Entire home/apt
# 3       Nicholas             Cuauhtémoc  19.41152  -99.16857  Entire home/apt
# 4         Trisha               Coyoacán  19.35448  -99.16217  Entire home/apt
# 5       Fernando               Coyoacán  19.35416  -99.16488     Private room
# 9         Julian             Cuauhtémoc  19.41057  -99.17730  Entire home/apt
# 10        Julian             Cuauhtémoc  19.41057  -99.17730  Entire home/apt
# 11        Julian             Cuauhtémoc  19.41057  -99.17730  Entire home/apt
# 18       Michael              Iztacalco  19.38061  -99.12729  Entire home/apt
# 19      Fernando             Cuauhtémoc  19.41108  -99.17634       Hotel room
# 21  Luis Ernesto          Benito Juárez  19.36305  -99.15412     Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0   3673.0               1                  0         NaN                NaN
# 3      NaN               2                 50  2024-10-30               0.30
# 4      NaN               3                134  2025-08-18               0.81
# 5      NaN               1                  0         NaN                NaN
# 9      NaN               4                103  2023-09-08               0.61
# 10     NaN              14                 24  2018-01-03               0.17
# 11     NaN               1                 77  2024-07-08               0.46
# 18     NaN               7                  0         NaN                NaN
# 19     NaN               1                  7  2019-10-05               0.05
# 21     NaN               2                  0         NaN                NaN
#
#     calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                1               363                      0
# 3                                2               252                      1
# 4                                3               234                      8
# 5                                3                 0                      0
# 9                                6                 0                      0
# 10                               6                 0                      0
# 11                               6                 0                      0
# 18                               1                 0                      0
# 19                               9               250                      0
# 21                               1                 0                      0

# %% [markdown]
# **3. Imputación y estandarización de valores nulos en columnas de texto:**
#
# * Sustituye los valores nulos de la columna `host_name` por la categoría `"Unidentified host"`.
# * Sustituye los valores nulos de la columna `last_review` por la categoría `"Never reviewed"`.
# * Elimina los espacios en blanco al inicio y al final de todas las columnas de tipo `object` del dataframe.

# %%
# Imputación por categoría
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].fillna("desconocido")

# %%
# Eliminar espacios extras
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip()

# %% [markdown]
# **4. Verificación de valores únicos y conversión de tipo de datos**
#
# * Visualiza los valores únicos de las columnas `neighbourhood` y  `room_type`.
# * Convierte las columnas `neighbourhood` y `room_type` al tipo de dato  `category`.
# * Convierte las columnas `id` y `host_id` al tipo de dato `object` y verifica los cambios.

# %%
# Observar valores únicos
print("neighbourhood:")
print(df["neighbourhood"].unique())

print("\nroom_type:")
print(df["room_type"].unique())
# Out:
# neighbourhood:
# ['Cuajimalpa de Morelos' 'Cuauhtémoc' 'Coyoacán' 'Miguel Hidalgo'
#  'Benito Juárez' 'Iztacalco' 'Tlalpan' 'Venustiano Carranza'
#  'Gustavo A. Madero' 'Xochimilco' 'Álvaro Obregón' 'Iztapalapa'
#  'La Magdalena Contreras' 'Azcapotzalco' 'Tláhuac' 'Milpa Alta']
#
# room_type:
# ['Entire home/apt' 'Private room' 'Hotel room' 'Shared room']

# %%
# Cambio de tipo de dato
df["neighbourhood"] = df["neighbourhood"].astype("category")
df["room_type"] = df["room_type"].astype("category")

# Convertir a object
df["id"] = df["id"].astype("object")
df["host_id"] = df["host_id"].astype("object")

# Verificar cambios
df.dtypes
# Out:
# id                                  object
# name                                object
# host_id                             object
# host_name                           object
# neighbourhood                     category
# latitude                           float64
# longitude                          float64
# room_type                         category
# price                              float64
# minimum_nights                       int64
# number_of_reviews                    int64
# last_review                         object
# reviews_per_month                  float64
# calculated_host_listings_count       int64
# availability_365                     int64
# number_of_reviews_ltm                int64
# dtype: object

# %% [markdown]
# **5. Análisis de valores nulos y de distribución para imputación en columnas numéricas:**
#
# * Cuantifica los valores nulos y el resumen estadístico de las columnas numéricas.
# * Genera un histograma para cada columna numérica con nulos.
# * Calcula la media y la desviación estándar de cada columna numérica.
# * Genera un gráfico de dispersión con limites de desviación estandar.

# %%
# Verificar valores nulos por columna numérica
df.select_dtypes(include=['int64', 'float64']).isnull().sum()
# Out:
# latitude                             0
# longitude                            0
# price                             3484
# minimum_nights                       0
# number_of_reviews                    0
# reviews_per_month                 3401
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# dtype: int64

# %%
# Ver resumen estadístico de las columnas con nulos
df.select_dtypes(include=['int64', 'float64']).describe()
# Out:
#            latitude     longitude          price  minimum_nights  \
# count  27051.000000  27051.000000   23567.000000    27051.000000
# mean      19.405490    -99.165385    1792.540841        4.580866
# std        0.042390      0.033535   13230.940558       24.784605
# min       19.177848    -99.339630      61.000000        1.000000
# 25%       19.392489    -99.178499     643.000000        1.000000
# 50%       19.415390    -99.167100    1039.000000        2.000000
# 75%       19.432015    -99.153731    1611.000000        2.000000
# max       19.561010    -98.963360  900000.000000     1125.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       27051.000000       23650.000000                    27051.000000
# mean           53.777679           1.854855                       14.559868
# std            85.143043           2.281154                       31.892178
# min             0.000000           0.010000                        1.000000
# 25%             4.000000           0.450000                        1.000000
# 50%            21.000000           1.260000                        3.000000
# 75%            69.000000           2.620000                       11.000000
# max          1434.000000         119.460000                      221.000000
#
#        availability_365  number_of_reviews_ltm
# count      27051.000000           27051.000000
# mean         232.686333              15.691028
# std          122.270858              23.615517
# min            0.000000               0.000000
# 25%          140.000000               0.000000
# 50%          269.000000               7.000000
# 75%          341.000000              23.000000
# max          365.000000             665.000000

# %%
# Observar distribución de las columnas con nulos
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:

    plt.figure(figsize=(8,5))

    sns.histplot(
        df[col],
        kde=True,
        bins=30
    )

    plt.title(f"Distribución de {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")
    plt.grid(True)

    plt.show()

# %%
# Calcular media y desviación estándar de las columnas con nulos
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:
    print(f"\nColumna: {col}")
    print("Media:", df[col].mean())
    print("Desviación estándar:", df[col].std())
# Out:
# Columna: latitude
# Media: 19.405490205869786
# Desviación estándar: 0.04239009539466327
#
# Columna: longitude
# Media: -99.16538515944562
# Desviación estándar: 0.03353462346372644
#
# Columna: price
# Media: 1792.5408410064922
# Desviación estándar: 13230.940557522046
#
# Columna: minimum_nights
# Media: 4.580865772060182
# Desviación estándar: 24.7846054539704
#
# Columna: number_of_reviews
# Media: 53.777679198550885
# Desviación estándar: 85.14304261986999
#
# Columna: reviews_per_month
# Media: 1.8548545454545453
# Desviación estándar: 2.2811537881451054
#
# Columna: calculated_host_listings_count
# Media: 14.5598683967321
# Desviación estándar: 31.892178444826143
#
# Columna: availability_365
# Media: 232.6863332224317
# Desviación estándar: 122.2708580102874
#
# Columna: number_of_reviews_ltm
# Media: 15.691028058112455
# Desviación estándar: 23.615516698313485

# %%
# Observar distribución de las columnas con nulos
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:

    plt.figure(figsize=(8,5))

    sns.histplot(
        data=df,
        x=col,
        kde=True,
        bins=30
    )

    plt.title(f"Distribución de {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")
    plt.grid(True)

    plt.show()

# %% [markdown]
# **6. Imputación de valores nulos en columnas numéricas y exportación final de datos**
#
# * Sustituye los valores nulos de la columna `price` por la **mediana**.
# * Sustituye los valores nulos de la columna `reviews_per_month` por **0**.
# * Exporta el dataframe procesado a un archivo CSV llamado `airbnb_clean.csv`.

# %%
# Imputación numérica
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
# Crear dataset final
# Crear copia final del dataset limpio
df_final = df.copy()

# Visualizar primeras filas
df_final.head()
# Out:
#       id                                              name host_id host_name  \
# 0  35797                                       Villa Dante  153786      Dici
# 1  44616                                      Condesa Haus  196253  Fernando
# 2  56074              Great space in historical San Rafael  265650     Maris
# 3  67703                 2 bedroom apt. deco bldg, Condesa  334451  Nicholas
# 4  70644  Beautiful light Studio Coyoacan- full equipped !  212109    Trisha
#
#            neighbourhood  latitude  longitude        room_type    price  \
# 0  Cuajimalpa de Morelos  19.38283  -99.27178  Entire home/apt   3673.0
# 1             Cuauhtémoc  19.41162  -99.17794  Entire home/apt  18000.0
# 2             Cuauhtémoc  19.43977  -99.15605  Entire home/apt    591.0
# 3             Cuauhtémoc  19.41152  -99.16857  Entire home/apt   1039.0
# 4               Coyoacán  19.35448  -99.16217  Entire home/apt   1039.0
#
#    minimum_nights  number_of_reviews  last_review  reviews_per_month  \
# 0               1                  0  desconocido               1.26
# 1               1                 65   2025-01-01               0.38
# 2              15                 84   2025-02-27               0.48
# 3               2                 50   2024-10-30               0.30
# 4               3                134   2025-08-18               0.81
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                               1               363                      0
# 1                               9               360                      1
# 2                               1               333                      1
# 3                               2               252                      1
# 4                               3               234                      8
