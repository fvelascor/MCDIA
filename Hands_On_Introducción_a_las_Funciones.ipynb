# %% [markdown]
# <a href="https://colab.research.google.com/github/fvelascor/MCDIA/blob/master/Hands_On_Introducci%C3%B3n_a_las_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HANDS - ON: INTRODUCCIÓN A LAS FUNCIONES**

# %% [markdown]
# Una vez visto la presentación ***Introducción a las funciones***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.
#
# De igual manera, se proporciona la **solución** de este notebook a través del siguiente [enlace](https://colab.research.google.com/drive/19WfNFwr8eu0YK3MGQh4RBczbKfbcqvgI?usp=sharing).

# %% [markdown]
# ## **FUNCIÓN INTEGRADA**

# %% [markdown]
# Una **función integrada** es un bloque de código reutilizable
#  predefinida en python que se utiliza para **realizar una tarea específica y están disponibles para su uso en cualquier momento** sin la necesidad de importar ningún módulo.

# %% [markdown]
# Una función integrada tiene la siguiente estructura:
#
# ```
# nombre_funcion(parametro1, parametro2, ...)
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Imprime una cadena de caracteres:

# %%
# difinir función
print('Hola mundo!')
# Out:
# Hola mundo!

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Devuelve la longitud de una lista:

# %%
# difinir función
len([1, 2, 3, 4, 5])
# Out:
# 5

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Devuelve una lista ordenada de elementos:

# %%
# difinir función
sorted([2, 4, 1, 5, 3])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Redondea un número según un número determinado de decimales:

# %%
# difinir función
round(3.14159265, 4)
# Out:
# 3.1416

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
# Devuelve el valor mínimo en una lista:

# %%
# difinir función
min((3, 6, 7, 2, 10, 2))
# Out:
# 2

# %% [markdown]
# ## **FUNCIÓN DEFINIDA POR EL USUARIO**

# %% [markdown]
# Una **función definida por el usuario** es creada de manera personalizada para realizar tareas específicas y reutilizables en todo el programa. Este tipo de función se crea utilizando la palabra clave ` def` seguida del nombre de la función y los parámetros, si los hay.

# %% [markdown]
# Una función definida por el usuario tiene la siguiente estructura:
#
# ```
# def nombre_funcion(parametro1, parametro2, ...):
#     # Código que realiza una tarea específica
#
#     # Devolver un valor (opcional)
#     return valor
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Función que calcula el cuadrado de un número:

# %%
# difinir función
num_cuad = int(input('Ingresa un número: '))

def cuadrado(numero):
    return numero ** 2

cuadrado(num_cuad)
# Out:
# Ingresa un número: 12
# 144

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Función para verificar si un número es par o impar:

# %%
# difinir función
num_par = int(input('Ingresa un número: '))

def par(numero):
    if numero % 2 == 0:
        print('Par')
    else:
        print('Impar')

par(num_par)
# Out:
# Ingresa un número: 5
# Impar

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Función para calcular el factorial de un número:

# %%
# difinir función
num_fact = int(input('Ingresa un número: '))

def factorial(numero):
    if numero == 0:
        return 1
    else:
        return numero * factorial(numero - 1)

factorial(num_fact)
# Out:
# Ingresa un número: 5
# 120

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Función para unir dos listas en una sola lista:

# %%
# definir listas
lista_1 = [1, 2]
lista_2 = [3, 4, 5]

# %%
# difinir función
def unir(lista1, lista2):
    lista_unida = lista1 + lista2
    return lista_unida

unir(lista_1, lista_2)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
#  Función para buscar elementos dentro de un diccionario

# %%
# definir diccionario
diccionario = {'México': 'Toluca', 'Monterrey': 'Nuevo León', 'Jalisco': 'Guadalajara'}

# %%
# difinir función
clave = input('Ingrese una clave: ')

def buscar(diccionario, clave):
    return diccionario.get(clave)

buscar(diccionario, clave)
# Out:
# Ingrese una clave: 45

# %% [markdown]
# ## **CHALLENGE: AGENDA CON MENÚ CRUD**

# %% [markdown]
# Una vez visto el ***Hands - On: Introducción a las funciones***, se presentan la siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se utilizará el challenge del menú** para **separar por funciones los procesos del CRUD** donde **cada función será invocado dentro del ciclo donde se muestra el menú**, todo lo anterior haciendo uso de **Python**.
#
# Cada función deberá ejecutar cada operación del CRUD:
#
# *   **Ver agenda**
# *   **Crear contacto**
# *   **Consultar contacto**
# *   **Actualizar contacto**
# *   **Eliminar contacto**
# *   **Salir menú**

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Crea la Agenda:** Construye la agenda con los registros utilizados en las prácticas anteriores.

# %%
# Definir agenda
# ------------------------------------------------------------
# CELDA 1: Definir agenda
# ------------------------------------------------------------

agenda = [
    {'nombre': 'Ana García',      'teléfono': '555-1001', 'correo': 'ana.garcia@email.com'},
    {'nombre': 'Carlos Pérez',    'teléfono': '555-2002', 'correo': 'carlos.perez@email.com'},
    {'nombre': 'María López',     'teléfono': '555-3003', 'correo': 'maria.lopez@email.com'},
    {'nombre': 'Fernando Torres', 'teléfono': '555-4004', 'correo': 'fernando.torres@email.com'},
    {'nombre': 'Lucía Martínez',  'teléfono': '555-5005', 'correo': 'lucia.martinez@email.com'}
]

# %% [markdown]
# **2. Define una función que muestre las opciones del menú CRUD:**
#
#    * Crea una función que muestre el menú CRUD para la agenda con las opciones:
#
#    ```
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#    ```

# %%
# Crear función menú opciones
# ------------------------------------------------------------
# CELDA 2: Función menú opciones
# ------------------------------------------------------------

def menu_opciones():
    print("\n" + "=" * 40)
    print("      📋 Menú CRUD - Agenda")
    print("=" * 40)
    print("  1. Ver agenda")
    print("  2. Crear contacto")
    print("  3. Consultar contacto")
    print("  4. Actualizar contacto")
    print("  5. Eliminar contacto")
    print("  6. Salir menú")
    print("=" * 40)

# %% [markdown]
# **3. Define una función que imprima todos los contactos de la agenda:**
#
#    * Crea una función que realice un ciclo for que recorra y muestre cada contacto de la agenda.
#    * Dentro del ciclo, muestra el número de contacto por cada iteración.

# %%
# Crear función mostrar agenda
# ------------------------------------------------------------
# CELDA 3: Función mostrar agenda
# ------------------------------------------------------------

def mostrar_agenda():
    print("\n" + "=" * 42)
    print("         📋 AGENDA DE CONTACTOS")
    print("=" * 42)

    for i in range(len(agenda)):
        print(f"\n  Contacto #{i + 1}")
        print("    Nombre   :", agenda[i]['nombre'])
        print("    Teléfono :", agenda[i]['teléfono'])
        print("    Correo   :", agenda[i]['correo'])

    print("\n" + "=" * 42)

# %% [markdown]
# **4. Define una función para crear un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre, teléfono y correo para un contacto.
#    * Guarda estos datos en un diccionario llamado contacto.
#    * Imprime el mensaje "Contacto creado con éxito".

# %%
# Crear función crear contacto
# ------------------------------------------------------------
# CELDA 4: Función crear contacto
# ------------------------------------------------------------

def crear_contacto():
    print("\n➕ CREAR NUEVO CONTACTO")
    nombre   = input("  Ingresa el nombre    : ")
    telefono = input("  Ingresa el teléfono  : ")
    correo   = input("  Ingresa el correo    : ")

    contacto = {
        'nombre':   nombre,
        'teléfono': telefono,
        'correo':   correo
    }

    agenda.append(contacto)
    print("✅ Contacto creado con éxito.")

# %% [markdown]
# **5. Define una función para consultar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a consultar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces imprime el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función consultar contacto
# ------------------------------------------------------------
# CELDA 5: Función consultar contacto
# ------------------------------------------------------------

def consultar_contacto():
    print("\n🔍 CONSULTAR CONTACTO")
    busqueda   = input("  Ingresa el nombre a consultar: ")
    encontrado = False

    for contacto in agenda:
        if contacto['nombre'].lower() == busqueda.lower():
            print("\n  Contacto encontrado:")
            print("    Nombre   :", contacto['nombre'])
            print("    Teléfono :", contacto['teléfono'])
            print("    Correo   :", contacto['correo'])
            encontrado = True
            break

    if not encontrado:
        print("  ❌ Contacto no encontrado.")

# %% [markdown]
# **6. Define una función para actualizar un contacto de la agenda:**
#
#  (Dada la complejidad y extensión de este punto se separará por partes).
#
#    * Crea una función que visualice un menú que contenga las siguientes opciones:
#
#    ```
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#    ```

# %%
# Crear función menú para actualizar contacto
# ------------------------------------------------------------
# CELDA 6a: Función menú para actualizar contacto
# ------------------------------------------------------------

def menu_actualizar():
    print("\n  Menú actualizar contacto:")
    print("    1. Actualizar nombre")
    print("    2. Actualizar teléfono")
    print("    3. Actualizar correo")
    print("    4. Salir del menú")

# %% [markdown]
#    * Crea una función que realice un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces retorna el contacto encontrado.
#    * De lo contrario, entonces retorna `None`.

# %%
# Crear función buscador contacto para actualizar contacto
# ------------------------------------------------------------
# CELDA 6b: Función buscador de contacto para actualizar
# ------------------------------------------------------------

def buscar_contacto(busqueda):
    for contacto in agenda:
        if contacto['nombre'].lower() == busqueda.lower():
            return contacto
    return None

# %% [markdown]
#    * Crea una función para cada opción a escojer, modificando ya sea el nombre, el teléfono o el correo del contacto encontrado por nuevos registros.
#    * Por cada registro nuevo ingresado, imprime el contacto para visualizar los cambios.

# %%
# Crear función actualizar nombre para actualizar contacto
# ------------------------------------------------------------
# CELDA 6c: Función actualizar nombre
# ------------------------------------------------------------

def actualizar_nombre(contacto):
    contacto['nombre'] = input("    Nuevo nombre: ")
    print("\n  Contacto actualizado:", contacto)

# %%
# Crear función actualizar telefono para actualizar contacto
# ------------------------------------------------------------
# CELDA 6d: Función actualizar teléfono
# ------------------------------------------------------------

def actualizar_telefono(contacto):
    contacto['teléfono'] = input("    Nuevo teléfono: ")
    print("\n  Contacto actualizado:", contacto)

# %%
# Crear función actualizar correo para actualizar contacto
# ------------------------------------------------------------
# CELDA 6e: Función actualizar correo
# ------------------------------------------------------------

def actualizar_correo(contacto):
    contacto['correo'] = input("    Nuevo correo: ")
    print("\n  Contacto actualizado:", contacto)

# %% [markdown]
#    * Crea una función que integre las funciones creadas anteriormente a través de un ciclo while para un menú de actualizar un contacto.
#    * Pide al usuario que ingrese el nombre del contacto a actualizar.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función actualizar contacto
# ------------------------------------------------------------
# CELDA 6f: Función integradora — actualizar contacto
# ------------------------------------------------------------

def actualizar_contacto():
    print("\n✏️  ACTUALIZAR CONTACTO")
    busqueda = input("  Ingresa el nombre del contacto a actualizar: ")
    contacto = buscar_contacto(busqueda)

    if contacto is None:
        print("  ❌ Contacto no encontrado.")
        return

    print("\n  Contacto encontrado:")
    print("    Nombre   :", contacto['nombre'])
    print("    Teléfono :", contacto['teléfono'])
    print("    Correo   :", contacto['correo'])

    while True:
        menu_actualizar()
        opcion = input("\n  Selecciona una opción: ")

        if opcion == '1':
            actualizar_nombre(contacto)
        elif opcion == '2':
            actualizar_telefono(contacto)
        elif opcion == '3':
            actualizar_correo(contacto)
        elif opcion == '4':
            print("  👋 Saliendo del menú de actualización.")
            break
        else:
            print("  ❌ Opción no encontrada.")

# %% [markdown]
# **7. Define una función para eliminar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a eliminar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces elimina el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función eliminar contacto
#------------------------------------------------------------
# CELDA 7: Función eliminar contacto
# ------------------------------------------------------------

def eliminar_contacto():
    print("\n🗑️  ELIMINAR CONTACTO")
    busqueda   = input("  Ingresa el nombre del contacto a eliminar: ")
    encontrado = False

    for contacto in agenda:
        if contacto['nombre'].lower() == busqueda.lower():
            agenda.remove(contacto)
            print(f"  ✅ Contacto '{contacto['nombre']}' eliminado con éxito.")
            encontrado = True
            break

    if not encontrado:
        print("  ❌ Contacto no encontrado.")

# %% [markdown]
# **8. Junta todas las funciones del menú CRUD dentro de una función:**
#
#    * Crea una función crear un menú a través de un ciclo while.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función menú agenda
# ------------------------------------------------------------
# CELDA 8: Función menú CRUD principal (orquestador)
# ------------------------------------------------------------

def menu_crud():
    while True:
        menu_opciones()
        opcion = input("\n  Selecciona una opción: ")

        if opcion == '1':
            mostrar_agenda()
        elif opcion == '2':
            crear_contacto()
        elif opcion == '3':
            consultar_contacto()
        elif opcion == '4':
            actualizar_contacto()
        elif opcion == '5':
            eliminar_contacto()
        elif opcion == '6':
            print("\n👋 Saliendo del menú CRUD. ¡Hasta luego!")
            break
        else:
            print("\n  ❌ Opción no encontrada.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_406/1119564295.py in <cell line: 0>()
#      30 # ------------------------------------------------------------
#      31
# ---> 32 menu_crud()
#
# /tmp/ipykernel_406/1119564295.py in menu_crud()
#       6 def menu_crud():
#       7     while True:
# ----> 8         menu_opciones()
#       9         opcion = input("\n  Selecciona una opción: ")
#      10
#
# NameError: name 'menu_opciones' is not defined

# %%
# ------------------------------------------------------------
# PUNTO DE ENTRADA — Ejecutar el menú
# ------------------------------------------------------------

menu_crud()
# Out:
# ========================================
#       📋 Menú CRUD - Agenda
# ========================================
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
# ========================================
#
#   Selecciona una opción: 1
#
# ==========================================
#          📋 AGENDA DE CONTACTOS
# ==========================================
#
#   Contacto #1
#     Nombre   : Ana García
#     Teléfono : 555-1001
#     Correo   : ana.garcia@email.com
#
#   Contacto #2
#     Nombre   : Carlos Pérez
#     Teléfono : 555-2002
#     Correo   : carlos.perez@email.com
#
#   Contacto #3
#     Nombre   : María López
#     Teléfono : 555-3003
#     Correo   : maria.lopez@email.com
#
#   Contacto #4
#     Nombre   : Fernando Torres
#     Teléfono : 555-4004
#     Correo   : fernando.torres@email.com
#
#   Contacto #5
#     Nombre   : Lucía Martínez
#     Teléfono : 555-5005
#     Correo   : lucia.martinez@email.com
#
# ==========================================
#
# ========================================
#       📋 Menú CRUD - Agenda
# ========================================
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
# ========================================
#
#   Selecciona una opción: 2
#
# ➕ CREAR NUEVO CONTACTO
#   Ingresa el nombre    : Daniel
#   Ingresa el teléfono  : 2227303764
#   Ingresa el correo    : daniel@contacto.com
# ✅ Contacto creado con éxito.
#
# ========================================
#       📋 Menú CRUD - Agenda
# ========================================
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
# ========================================
#
#   Selecciona una opción: 1
#
# ==========================================
#          📋 AGENDA DE CONTACTOS
# ==========================================
#
#   Contacto #1
#     Nombre   : Ana García
#     Teléfono : 555-1001
#     Correo   : ana.garcia@email.com
#
#   Contacto #2
#     Nombre   : Carlos Pérez
#     Teléfono : 555-2002
#     Correo   : carlos.perez@email.com
#
#   Contacto #3
#     Nombre   : María López
#     Teléfono : 555-3003
#     Correo   : maria.lopez@email.com
#
#   Contacto #4
#     Nombre   : Fernando Torres
#     Teléfono : 555-4004
#     Correo   : fernando.torres@email.com
#
#   Contacto #5
#     Nombre   : Lucía Martínez
#     Teléfono : 555-5005
#     Correo   : lucia.martinez@email.com
#
#   Contacto #6
#     Nombre   : Daniel
#     Teléfono : 2227303764
#     Correo   : daniel@contacto.com
#
# ==========================================
#
# ========================================
#       📋 Menú CRUD - Agenda
# ========================================
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
# ========================================
#
#   Selecciona una opción: 6
#
# 👋 Saliendo del menú CRUD. ¡Hasta luego!
